# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Dataset Project 404.xlsx", sheet_name="original")

# %%
df = df[features + [target]].copy()
df[target] = df[target].astype(str).str.strip()
df = df.dropna()

# %%
features = [
    'Linguistic',
    'Musical',
    'Bodily',
    'Logical - Mathematical',
    'Spatial-Visualization',
    'Interpersonal',
    'Intrapersonal',
    'Naturalist'
]
# Target column (career/job recommendation)
target = 'Job profession'

# %%
# 5. Prepare X and y
X = df[features].values
y = df[target].values

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Convert target into one-hot encoding
y_categorical = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42, stratify=y_encoded
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(y_categorical.shape[1], activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1089 - loss: 3.8299 - val_accuracy: 0.3646 - val_loss: 2.8688
# Epoch 2/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4518 - loss: 2.1601 - val_accuracy: 0.7535 - val_loss: 1.2134
# Epoch 3/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6111 - loss: 1.2843 - val_accuracy: 0.8160 - val_loss: 0.7249
# Epoch 4/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6797 - loss: 0.9839 - val_accuracy: 0.8333 - val_loss: 0.5752
# Epoch 5/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7144 - loss: 0.8357 - val_accuracy: 0.8750 - val_loss: 0.4660
# Epoch 6/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7574 - loss: 0.7250 - val_accuracy: 0.8611 - val_loss: 0.4196
# Epoch 7/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7769 - loss: 0.6399 - val_accuracy: 0.8958 - val_loss: 0.3629
# Epoch 8/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7678 - loss: 0.6450 - val_accuracy: 0.8854 - val_loss: 0.3568
# Epoch 9/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8090 - loss: 0.5382 - val_accuracy: 0.8924 - val_loss: 0.3198
# Epoch 10/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8051 - loss: 0.5379 - val_accuracy: 0.8854 - val_loss: 0.3131
# Epoch 11/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8051 - loss: 0.5274 - val_accuracy: 0.9028 - val_loss: 0.2915
# Epoch 12/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8095 - loss: 0.4928 - val_accuracy: 0.8958 - val_loss: 0.2891
# Epoch 13/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8216 - loss: 0.4655 - val_accuracy: 0.8958 - val_loss: 0.2749
# Epoch 14/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8303 - loss: 0.4586 - val_accuracy: 0.9045 - val_loss: 0.2726
# Epoch 15/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8333 - loss: 0.4469 - val_accuracy: 0.8837 - val_loss: 0.2676
# Epoch 16/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8355 - loss: 0.4375 - val_accuracy: 0.8941 - val_loss: 0.2619
# Epoch 17/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8281 - loss: 0.4287 - val_accuracy: 0.8889 - val_loss: 0.2719
# Epoch 18/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8442 - loss: 0.4172 - val_accuracy: 0.8872 - val_loss: 0.2677
# Epoch 19/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8372 - loss: 0.4044 - val_accuracy: 0.9028 - val_loss: 0.2469
# Epoch 20/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8511 - loss: 0.3909 - val_accuracy: 0.8976 - val_loss: 0.2521
# Epoch 21/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8546 - loss: 0.3888 - val_accuracy: 0.9028 - val_loss: 0.2355
# Epoch 22/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8485 - loss: 0.3646 - val_accuracy: 0.8958 - val_loss: 0.2419
# Epoch 23/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8589 - loss: 0.3633 - val_accuracy: 0.9149 - val_loss: 0.2305
# Epoch 24/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.3426 - val_accuracy: 0.9010 - val_loss: 0.2374
# Epoch 25/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8581 - loss: 0.3540 - val_accuracy: 0.8976 - val_loss: 0.2439
# Epoch 26/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8589 - loss: 0.3459 - val_accuracy: 0.9115 - val_loss: 0.2213
# Epoch 27/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8633 - loss: 0.3420 - val_accuracy: 0.8993 - val_loss: 0.2232
# Epoch 28/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8572 - loss: 0.3364 - val_accuracy: 0.9115 - val_loss: 0.2216
# Epoch 29/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8633 - loss: 0.3308 - val_accuracy: 0.9236 - val_loss: 0.2110
# Epoch 30/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 0.3345 - val_accuracy: 0.9132 - val_loss: 0.2145
# Epoch 31/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8650 - loss: 0.3290 - val_accuracy: 0.9115 - val_loss: 0.2212
# Epoch 32/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8672 - loss: 0.3281 - val_accuracy: 0.9115 - val_loss: 0.2161
# Epoch 33/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8685 - loss: 0.3296 - val_accuracy: 0.9028 - val_loss: 0.2129
# Epoch 34/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8694 - loss: 0.3077 - val_accuracy: 0.9115 - val_loss: 0.2207
# Epoch 35/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.3080 - val_accuracy: 0.9167 - val_loss: 0.2143
# Epoch 36/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.3013 - val_accuracy: 0.9219 - val_loss: 0.2061
# Epoch 37/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8785 - loss: 0.2969 - val_accuracy: 0.9253 - val_loss: 0.1971
# Epoch 38/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8776 - loss: 0.2914 - val_accuracy: 0.9149 - val_loss: 0.2036
# Epoch 39/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8711 - loss: 0.2967 - val_accuracy: 0.9184 - val_loss: 0.2030
# Epoch 40/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8802 - loss: 0.2942 - val_accuracy: 0.9132 - val_loss: 0.1968
# Epoch 41/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8828 - loss: 0.2895 - val_accuracy: 0.9115 - val_loss: 0.1958
# Epoch 42/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8772 - loss: 0.2900 - val_accuracy: 0.9358 - val_loss: 0.1769
# Epoch 43/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2590 - val_accuracy: 0.9149 - val_loss: 0.1880
# Epoch 44/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8789 - loss: 0.2799 - val_accuracy: 0.9271 - val_loss: 0.1875
# Epoch 45/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8880 - loss: 0.2694 - val_accuracy: 0.9358 - val_loss: 0.1796
# Epoch 46/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8828 - loss: 0.2807 - val_accuracy: 0.9149 - val_loss: 0.2029
# Epoch 47/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8928 - loss: 0.2769 - val_accuracy: 0.9149 - val_loss: 0.1877
# Epoch 48/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8915 - loss: 0.2712 - val_accuracy: 0.9271 - val_loss: 0.1929
# Epoch 49/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8924 - loss: 0.2653 - val_accuracy: 0.9167 - val_loss: 0.1942
# Epoch 50/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8924 - loss: 0.2801 - val_accuracy: 0.9219 - val_loss: 0.1944

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print("\nTest Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Loss: 0.1921454519033432
# Test Accuracy: 0.9277777671813965

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print("\nClassification Metrics:")
print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1-Score :", f1)
# Out:
# Classification Metrics:
# Accuracy : 0.9277777777777778
# Precision: 0.9251868501868502
# Recall   : 0.9277777777777778
# F1-Score : 0.9217207235721392

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_, zero_division=0))
# Out:
# Classification Report:
#
#                                                                                                 precision    recall  f1-score   support
#
#                                                                                Actor / Actress       0.83      1.00      0.91        10
#                                                                                        Actuary       0.91      1.00      0.95        10
#                                                                                 Anthropologist       1.00      1.00      1.00        10
#                                                                                   Archeologist       1.00      1.00      1.00        10
#                                                                                         Artist       1.00      1.00      1.00        10
#                                                                                     Astronomer       1.00      1.00      1.00        10
#                                                                                        Athlete       1.00      0.80      0.89        10
#                                                                                    Audiologist       0.90      0.90      0.90        10
#                                                                                        Banking       1.00      1.00      1.00        10
#                                                                                    Broadcaster       1.00      1.00      1.00        10
#                                                                               Business Analyst       0.91      1.00      0.95        10
#                                                                               Business manager       0.60      0.30      0.40        10
#                                                                           Chartered Accountant       1.00      1.00      1.00        10
#                                                                        Chief financial officer       0.91      1.00      0.95        10
#                                                                              Company secretary       0.70      0.70      0.70        10
#                                                                               Computer analyst       0.91      1.00      0.95        10
#                                                                            Computer programmer       1.00      1.00      1.00        10
#                                                                                     Consultant       0.57      0.40      0.47        10
#                                                                                      Counselor       0.91      1.00      0.95        10
#                                                                                  Criminologist       1.00      1.00      1.00        10
#                                                                                         Dancer       1.00      1.00      1.00        10
#                                                                              Database designer       1.00      1.00      1.00        10
#                                                                                      Economist       0.83      1.00      0.91        10
#                                                                                         Editor       1.00      1.00      1.00        10
#                                                                                       Engineer       1.00      1.00      1.00        10
#                                                                               Fashion Designer       1.00      1.00      1.00        10
#                                                                              Financial Advisor       0.64      0.90      0.75        10
#                                                                                      Geologist       1.00      1.00      1.00        10
#                                                                               Graphic Designer       1.00      1.00      1.00        10
#                                                                                      Historian       1.00      1.00      1.00        10
#                                                                             Interior Decorator       1.00      1.00      1.00        10
#                                                                               Internal auditor       0.90      0.90      0.90        10
#                                                                                     Journalist       0.90      0.90      0.90        10
#                                                                               Language Teacher       1.00      1.00      1.00        10
#                                                                                         Lawyer       1.00      1.00      1.00        10
#                                                                                         Leader       1.00      0.50      0.67        10
#                                                                                      Librarian       0.91      1.00      0.95        10
#                                                                              Logistics manager       0.57      0.40      0.47        10
#                                                                                        Manager       1.00      1.00      1.00        10
#                                                                               Marine Biologist       1.00      1.00      1.00        10
#                                                                                      Marketing       1.00      1.00      1.00        10
#                                                                                  Mathematician       1.00      1.00      1.00        10
#                                                                                       Mechanic       1.00      1.00      1.00        10
#                                                                                        Medical       0.91      1.00      0.95        10
#                                                   Middle, Higher School Teacher and Professors       1.00      0.90      0.95        10
#                                                                                        Militry       0.50      0.70      0.58        10
#                                                                                  Music teacher       1.00      1.00      1.00        10
#                                                                            Nature photographer       1.00      1.00      1.00        10
# Para Medical (physiotherapy, occupational theropy, audio and speech language theropy, nursing)       1.00      1.00      1.00        10
#                      Para Militry (https://en.wikipedia.org/wiki/Paramilitary_forces_of_India)       0.54      0.70      0.61        10
#                                                                                     Pharmacist       0.90      0.90      0.90        10
#                                                                                    Philosopher       1.00      1.00      1.00        10
#                                                                             Physical Therapist       1.00      1.00      1.00        10
#                                                                                      Physician       1.00      0.90      0.95        10
#                                                                                      Physicist       1.00      1.00      1.00        10
#                                                                                          Pilot       1.00      1.00      1.00        10
#                                                                                           Poet       1.00      1.00      1.00        10
#                                           Police Force (Spies, CBI officials, CID, Detectives)       0.33      0.10      0.15        10
#                                                                                     Politician       0.83      1.00      0.91        10
#                                               Pre Primary Teacher (2020 NEP and Mental Health)       1.00      1.00      1.00        10
#                                                                                Primary Teacher       1.00      1.00      1.00        10
#                                                                                   Psychologist       1.00      1.00      1.00        10
#                                                                                   Receptionist       1.00      1.00      1.00        10
#                                                                             Recording engineer       1.00      1.00      1.00        10
#                                                                               Research analyst       1.00      1.00      1.00        10
#                                                                           Sales Representative       1.00      1.00      1.00        10
#                                                                                  Social Worker       1.00      1.00      1.00        10
#                                                                                   Sound editor       1.00      1.00      1.00        10
#                                                                                   Stock Broker       0.69      0.90      0.78        10
#                                                                                     Technician       1.00      1.00      1.00        10
#                                                                                   Veterinarian       1.00      1.00      1.00        10
#                                                                                         Writer       1.00      1.00      1.00        10
#
#                                                                                       accuracy                           0.93       720
#                                                                                      macro avg       0.93      0.93      0.92       720
#                                                                                   weighted avg       0.93      0.93      0.92       720

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 18. Predict career for a new student
sample_student = np.array([[15, 8, 12, 18, 16, 14, 17, 10]])
# Example order:
# Linguistic, Musical, Bodily, Logical-Mathematical, Spatial-Visualization,
# Interpersonal, Intrapersonal, Naturalist

sample_student_scaled = scaler.transform(sample_student)
sample_pred = model.predict(sample_student_scaled)
predicted_class = np.argmax(sample_pred, axis=1)[0]
predicted_job = label_encoder.inverse_transform([predicted_class])[0]

print("\nRecommended Career Path for sample student:", predicted_job)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# Recommended Career Path for sample student: Engineer
